# %%
#import seluruh module yang dibutuhkan
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#membaca dataset
data = pd.read_csv('CADdataset.csv')

# %%
#memahami data dan atribut dalam dataset
data.head()
# Out:
#    Age  Weight  Height    Sex        BMI  DM  HTN  Current Smoker Obesity DLP  \
# 0   53      90     175   Male  29.387755   0    1               1       Y   Y
# 1   67      70     157  Fmale  28.398718   0    1               0       Y   N
# 2   54      54     164   Male  20.077335   0    0               1       N   N
# 3   66      67     158  Fmale  26.838648   0    1               0       Y   N
# 4   50      87     153  Fmale  37.165193   0    1               0       Y   N
#
#    ...  LVH PRP  FBS ESR  EF   RWMA  EX-Smoker   CR BUN     CAD
# 0  ...    N   N   90   7  50      0          0  0.7   8     Cad
# 1  ...    N   N   80  26  40      4          0  1.0  30     Cad
# 2  ...    N   N   85  10  40      2          0  1.0  17     Cad
# 3  ...    N   N   78  76  55      0          0  1.2  30  Normal
# 4  ...    N   N  104  27  50      0          0  1.0  16  Normal
#
# [5 rows x 27 columns]

# %%
#memahami bentuk data dalam dataset
data.shape
# Out:
# (303, 27)

# %%
#memahami data dan  atribut dalam dataset
data.describe()
# Out:
#               Age      Weight      Height         BMI          DM         HTN  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    58.897690   73.831683  164.716172   27.248339    0.297030    0.590759
# std     10.392278   11.987358    9.327661    4.098865    0.457706    0.492507
# min     30.000000   48.000000  140.000000   18.115413    0.000000    0.000000
# 25%     51.000000   65.000000  158.000000   24.514380    0.000000    0.000000
# 50%     58.000000   74.000000  165.000000   26.775510    0.000000    1.000000
# 75%     66.000000   81.000000  171.000000   29.411765    1.000000    1.000000
# max     86.000000  120.000000  188.000000   40.900658    1.000000    1.000000
#
#        Current Smoker          BP  Typical Chest Pain  St Depression  \
# count      303.000000  303.000000          303.000000     303.000000
# mean         0.207921  129.554455            0.541254       0.234323
# ...

# %%
#memahami data dan atribut dalam dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 303 non-null    int64
#  1   Weight              303 non-null    int64
#  2   Height              303 non-null    int64
#  3   Sex                 303 non-null    object
#  4   BMI                 303 non-null    float64
#  5   DM                  303 non-null    int64
#  6   HTN                 303 non-null    int64
#  7   Current Smoker      303 non-null    int64
#  8   Obesity             303 non-null    object
#  9   DLP                 303 non-null    object
#  10  BP                  303 non-null    int64
#  11  WPE                 303 non-null    object
#  12  Typical Chest Pain  303 non-null    int64
#  13  Atypical            303 non-null    object
#  14  Nonanginal          303 non-null    object
# ...

# %%
#mengecek null
data.isnull().sum()
# Out:
# Age                   0
# Weight                0
# Height                0
# Sex                   0
# BMI                   0
# DM                    0
# HTN                   0
# Current Smoker        0
# Obesity               0
# DLP                   0
# BP                    0
# WPE                   0
# Typical Chest Pain    0
# Atypical              0
# Nonanginal            0
# St Depression         0
# Tinversion            0
# LVH                   0
# PRP                   0
# FBS                   0
# ESR                   0
# EF                    0
#  RWMA                 0
# EX-Smoker             0
# CR                    0
# BUN                   0
# CAD                   0
# dtype: int64

# %%
data.apply(lambda x: len(x.unique()))
# Out:
# Age                    46
# Weight                 54
# Height                 44
# Sex                     2
# BMI                   262
# DM                      2
# HTN                     2
# Current Smoker          2
# Obesity                 2
# DLP                     2
# BP                     17
# WPE                     2
# Typical Chest Pain      2
# Atypical                2
# Nonanginal              2
# St Depression           2
# Tinversion              2
# LVH                     2
# PRP                     2
# FBS                   113
# ESR                    58
# EF                     11
#  RWMA                   5
# EX-Smoker               2
# CR                     18
# BUN                    33
# CAD                     2
# dtype: int64

# %%
data['Weight'].value_counts()
# Out:
# 75     22
# 80     16
# 70     16
# 74     12
# 64     11
# 60     11
# 63     10
# 65     10
# 73     10
# 66      9
# 82      9
# 76      8
# 67      8
# 78      8
# 72      8
# 90      7
# 89      7
# 68      7
# 84      7
# 81      7
# 85      6
# 88      6
# 79      6
# 61      6
# 83      5
# 62      5
# 54      5
# 71      5
# 55      4
# 57      4
# 87      3
# 92      3
# 53      3
# 98      3
# 69      3
# 58      3
# 50      3
# 100     2
# 77      2
# 56      2
# 59      2
# 95      2
# 97      2
# 91      2
# 86      2
# 48      2
# 108     2
# 94      1
# 102     1
# 93      1
# 103     1
# 51      1
# 120     1
# 105     1
# Name: Weight, dtype: int64

# %%
f,ax=plt.subplots(figsize=(12,6))
corr=data.corr()
sns.heatmap(corr , ax=ax , cmap="rocket")
# Out:
# <ipython-input-29-13d5dd31de7e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=data.corr()
# <Axes: >

# %%
data.columns
# Out:
# Index(['Age', 'Weight', 'Height', 'Sex', 'BMI', 'DM', 'HTN', 'Current Smoker',
#        'Obesity', 'DLP', 'BP', 'WPE', 'Typical Chest Pain', 'Atypical',
#        'Nonanginal', 'St Depression', 'Tinversion', 'LVH', 'PRP', 'FBS', 'ESR',
#        'EF', ' RWMA', 'EX-Smoker', 'CR', 'BUN', 'CAD'],
#       dtype='object')

# %%
f= plt.figure(figsize=(20,5))
ax=f.add_subplot(121)
sns.distplot(data['Weight'] , color ='yellow',ax=ax)

ax=f.add_subplot(122)
sns.distplot(data['Height'] , color='blue' , ax=ax)
plt.tight_layout()
# Out:
# <ipython-input-32-8413f8ef9de1>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Weight'] , color ='yellow',ax=ax)
# <ipython-input-32-8413f8ef9de1>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Height'] , color='blue' , ax=ax)

# %%
f= plt.figure(figsize=(20,5))
ax=f.add_subplot(121)
sns.distplot(data['BMI'] , color ='green',ax=ax)

ax=f.add_subplot(122)
sns.distplot(data['DM'] , color='black' , ax=ax)
plt.tight_layout()
# Out:
# <ipython-input-41-7c15a5534246>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['BMI'] , color ='green',ax=ax)
# <ipython-input-41-7c15a5534246>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['DM'] , color='black' , ax=ax)

# %%
f= plt.figure(figsize=(20,5))
ax=f.add_subplot(121)
sns.distplot(data['ESR'] , color ='blue',ax=ax)

ax=f.add_subplot(122)
sns.distplot(data['EX-Smoker'] , color='red' , ax=ax)
plt.tight_layout()
# Out:
# <ipython-input-43-7814f3ccd491>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['ESR'] , color ='blue',ax=ax)
# <ipython-input-43-7814f3ccd491>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['EX-Smoker'] , color='red' , ax=ax)

# %%
sns.barplot(x=data['Weight'].value_counts().index,
y=data['Weight'].value_counts(), palette='Spectral')
plt.xticks(rotation=90)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
#atribut biasa
x = data.drop(columns='Weight')
x.head()
# Out:
#    Age  Height    Sex        BMI  DM  HTN  Current Smoker Obesity DLP   BP  \
# 0   53     175   Male  29.387755   0    1               1       Y   Y  110
# 1   67     157  Fmale  28.398718   0    1               0       Y   N  140
# 2   54     164   Male  20.077335   0    0               1       N   N  100
# 3   66     158  Fmale  26.838648   0    1               0       Y   N  100
# 4   50     153  Fmale  37.165193   0    1               0       Y   N  110
#
#    ... LVH  PRP  FBS ESR  EF   RWMA EX-Smoker   CR  BUN     CAD
# 0  ...   N    N   90   7  50      0         0  0.7    8     Cad
# 1  ...   N    N   80  26  40      4         0  1.0   30     Cad
# 2  ...   N    N   85  10  40      2         0  1.0   17     Cad
# 3  ...   N    N   78  76  55      0         0  1.2   30  Normal
# 4  ...   N    N  104  27  50      0         0  1.0   16  Normal
#
# [5 rows x 26 columns]

# %%
#atribut spesial
y = data['Weight']
y.head()
# Out:
# 0    90
# 1    70
# 2    54
# 3    67
# 4    87
# Name: Weight, dtype: int64

# %%
# split data menjadi data training(70%) dan data tresting (30%)
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.3, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# Menggunakan algoritma DT
dt = DecisionTreeClassifier()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# Menggunakan algoritma K-NN
knn = KNeighborsClassifier(n_neighbors=5, weights='distance', p=2, metric='euclidean')
